# %%
from ayse import DataOperations
import numpy as np
import pandas as pd
import sklearn
import os
from columnar import columnar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
operator = DataOperations()
# Out:
# DataOperations object created.

# %%
PATH = "path_to_directory"
data_from_directory = operator.read_data_from_directory(PATH)
data_from_directory.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
random_created_data = operator.create_random_dataframe()
random_created_data.head()
# Out:
#    feature0  feature1  feature2  feature3  feature4  label
# 0  0.514319  1.785449 -0.193515 -0.766995  1.155438      1
# 1 -2.366833  0.190062  1.067651 -1.968926  2.110471      1
# 2 -2.139974  0.288466  1.394757 -1.856487  2.011227      1
# 3  0.625988 -0.828772 -0.743985  1.029955 -1.246041      0
# 4 -0.274683 -0.601345  0.066168  0.179254 -0.305885      0

# %%
array = np.random.randn(100, 5)
data_from_np = operator.read_data_from_numpy(array)
data_from_np.head()
# Out:
#    feature0  feature1  feature2  feature3  feature4
# 0 -0.479436  0.523513  0.700913  0.271655 -1.728342
# 1 -0.802453  0.377236 -1.247519 -0.163414 -0.413205
# 2  0.845296 -0.576435 -1.967255  1.142329 -0.060162
# 3  0.727719  0.613636 -0.366344 -0.039928  0.328685
# 4  0.250330  0.927981 -0.545050  0.025394  1.468204

# %%
operator.analyse(data_from_directory)
# Out:
#
#      NAME       DTYPE   NUMBER OF U  MEAN   MEDIAN  MODE    STD    MAX    MIN
#                         NIQUE VALUE
#                              S
#       Id        int64       150      75.5    75.5     1    43.45   150     1
#   SepalLength  float64      35       5.84    5.8     5.0   0.83    7.9    4.3
#       Cm
#   SepalWidthC  float64      23       3.05    3.0     3.0   0.43    4.4    2.0
#        m
#   PetalLength  float64      43       3.76    4.35    1.5   1.76    6.9    1.0
#       Cm
#   PetalWidthC  float64      22        1.2    1.3     0.2   0.76    2.5    0.1
#        m
#
#
#    NAME    DTYPE   NUMBER OF UNIQUE VALUES     MODE
#   Species  object             3             Iris-setosa

# %%
operator.fast_plot(data_from_directory, target="Species", idx="Id")

# %%
operator.analyse(random_created_data)
# Out:
#
#    NAME     DTYPE   NUMBER   MEAN   MEDIAN    MODE     STD     MAX      MIN
#                     OF UNIQ
#                     UE VALU
#                       ES
#   feature  float64    100    0.14   0.03955  -3.6111   1.4   4.12331  -3.6111
#      0                              7627651  7076834         2401884  7076834
#                                      72327    04477            321     04477
#   feature  float64    100    0.02   -0.1055  -2.1481  1.23   3.08678  -2.1481
#      1                              6385253  5841077         3979676  5841077
#                                     550649    49914            788     49914
#   feature  float64    100    0.01   0.04603  -2.7218  1.08   2.90406  -2.7218
#      2                              6682462  9265471         1207631  9265471
#                                      92188    60107            828     60107
#   feature  float64    100    0.09   0.01813  -1.9689  1.27   3.48479  -1.9689
# ...

# %%
operator.fast_plot(random_created_data, target="label")

# %%
operator.analyse(data_from_np)
# Out:
#
#    NAME     DTYPE   NUMBER   MEAN   MEDIAN    MODE     STD     MAX      MIN
#                     OF UNIQ
#                     UE VALU
#                       ES
#   feature  float64    100    -0.01  0.00192  -1.9463  0.92   1.88222  -1.9463
#      0                              7428119  2886380         8389913  2886380
#                                     3685755   88625           1307     88625
#   feature  float64    100    -0.13  -0.1216  -2.8318  1.09   2.20520  -2.8318
#      1                              3211098  8276778         8299685  8276778
#                                     625243    44896           4874     44896
#   feature  float64    100    -0.1   -0.0424  -2.9221  1.04   2.74844  -2.9221
#      2                              9022955  2582621         5254543  2582621
#                                     8166955   01597           9395     01597
#   feature  float64    100    0.17   0.09576  -2.3173  1.02   2.62826  -2.3173
# ...

# %%
operator.fast_plot(data_from_np)
